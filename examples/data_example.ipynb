# %%
# %matplotlib widget
from easydynamics.experiment   import Data
import plopp as pp
import scipp as sc

vanadium_data=Data.load_example_vanadium_data()

vanadium_data.transpose().plot()

# %%
MyData=Data(name='test')
MyData.append(vanadium_data)

a=MyData.create_data_1D(Q_bins=None, energy_bins=sc.scalar(1e-3*0.3, unit='meV'))


a.plot()

# %%
vanadium_data.coords['Q']

# %%
vanadium_data.sizes
q_val=vanadium_data.coords['Q'][3].values

slice=vanadium_data['Q', 3]

slice.plot()

# %%
for Q_index in range(vanadium_data.sizes['Q']):
    print(Q_index)
